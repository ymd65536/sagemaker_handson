# %%
import pandas as pd
pd.read_csv('https://www.mhlw.go.jp/content/pcr_tested_daily.csv',encoding='UTF-8',index_col=False)
# Out:
#            日付  PCR 検査実施件数(単日)
# 0    2020/2/5             4.0
# 1    2020/2/6            19.0
# 2    2020/2/7             9.0
# 3    2020/2/8             4.0
# 4    2020/2/9            10.0
# ..        ...             ...
# 545  2021/8/3         83159.0
# 546  2021/8/4        100583.0
# 547  2021/8/5        114844.0
# 548  2021/8/6        112653.0
# 549  2021/8/7         71501.0
#
# [550 rows x 2 columns]
